# %% [markdown]
# ## Covid-19 Impact Analysis

# %%
import numpy as np
import pandas as pd

# %%
patient =pd.read_csv('state_wise_daily data.csv')

# %%
patient
# Out:
#            Date    Date_YMD     Status  Total  Hospitalized  Recovered  \
# 0     14-Mar-20  14-03-2020  Confirmed     81            12        120
# 1     14-Mar-20  14-03-2020  Recovered      9            25          5
# 2     14-Mar-20  14-03-2020   Deceased      2            85         10
# 3     15-Mar-20  15-03-2020  Confirmed     27            89         15
# 4     15-Mar-20  15-03-2020  Recovered      4            10          5
# ...         ...         ...        ...    ...           ...        ...
# 1786  30-Oct-21  30-10-2021  Recovered  14672             0         14
# 1787  30-Oct-21  30-10-2021   Deceased    445            22          1
# 1788  31-Oct-21  31-10-2021  Confirmed  12907            50         20
# 1789  31-Oct-21  31-10-2021  Recovered  13152             1         23
# 1790  31-Oct-21  31-10-2021   Deceased    251            23          0
#
#       Deceased  Mask  Sanitizer  Oxygen  ...  RJ  SK    TN   TG  TR  UP  UT  \
# 0            0    10         60      48  ...   3   0     1    1   0  12   0
# 1            2    20          1      38  ...   1   0     0    0   0   4   0
# 2            4    30          0       0  ...   0   0     0    0   0   0   0
# 3            0    40         41      57  ...   1   0     0    2   0   1   0
# 4           21    50          4      55  ...   2   0     0    1   0   0   0
# ...        ...   ...        ...     ...  ...  ..  ..   ...  ...  ..  ..  ..
# 1786        10   371          2       2  ...   1   3  1172  191   8   9   6
# 1787         0     4          0       0  ...   0   0    14    1   0   0   0
# 1788         1   212          8       5  ...   2  21  1009  121  12   6   5
# 1789         9   236          9       3  ...   2   8  1183  183   2   6   9
# 1790         0     1          0       0  ...   0   1    19    1   0   0   0
#
#        WB  UN        State
# 0       0   0  Maharashtra
# 1       0   0  Maharashtra
# 2       0   0  Maharashtra
# 3       0   0  Maharashtra
# 4       0   0  Maharashtra
# ...   ...  ..          ...
# 1786  880   0   Lakshdweep
# 1787   13   0   Lakshdweep
# 1788  914   0   Lakshdweep
# 1789  913   0   Lakshdweep
# 1790   15   0   Lakshdweep
#
# [1791 rows x 43 columns]

# %%
patient['Status']
# Out:
# 0       Confirmed
# 1       Recovered
# 2        Deceased
# 3       Confirmed
# 4       Recovered
#           ...
# 1786    Recovered
# 1787     Deceased
# 1788    Confirmed
# 1789    Recovered
# 1790     Deceased
# Name: Status, Length: 1791, dtype: object

# %%
patient['Status'].value_counts()
# Out:
# Status
# Confirmed    597
# Recovered    597
# Deceased     597
# Name: count, dtype: int64

# %%
total=patient.shape[0]

# %%
total
# Out:
# 1791

# %%
active=patient[patient['Status']=='Confirmed'].shape[0]

# %%
active
# Out:
# 597

# %%
recover=patient[patient['Status']=='Recovered'].shape[0]

# %%
recover
# Out:
# 597

# %%
deaths=patient[patient['Status']=='Deceased'].shape[0]

# %%
deaths
# Out:
# 597

# %%
patient
# Out:
#            Date    Date_YMD     Status  Total  Hospitalized  Recovered  \
# 0     14-Mar-20  14-03-2020  Confirmed     81            12        120
# 1     14-Mar-20  14-03-2020  Recovered      9            25          5
# 2     14-Mar-20  14-03-2020   Deceased      2            85         10
# 3     15-Mar-20  15-03-2020  Confirmed     27            89         15
# 4     15-Mar-20  15-03-2020  Recovered      4            10          5
# ...         ...         ...        ...    ...           ...        ...
# 1786  30-Oct-21  30-10-2021  Recovered  14672             0         14
# 1787  30-Oct-21  30-10-2021   Deceased    445            22          1
# 1788  31-Oct-21  31-10-2021  Confirmed  12907            50         20
# 1789  31-Oct-21  31-10-2021  Recovered  13152             1         23
# 1790  31-Oct-21  31-10-2021   Deceased    251            23          0
#
#       Deceased  Mask  Sanitizer  Oxygen  ...  RJ  SK    TN   TG  TR  UP  UT  \
# 0            0    10         60      48  ...   3   0     1    1   0  12   0
# 1            2    20          1      38  ...   1   0     0    0   0   4   0
# 2            4    30          0       0  ...   0   0     0    0   0   0   0
# 3            0    40         41      57  ...   1   0     0    2   0   1   0
# 4           21    50          4      55  ...   2   0     0    1   0   0   0
# ...        ...   ...        ...     ...  ...  ..  ..   ...  ...  ..  ..  ..
# 1786        10   371          2       2  ...   1   3  1172  191   8   9   6
# 1787         0     4          0       0  ...   0   0    14    1   0   0   0
# 1788         1   212          8       5  ...   2  21  1009  121  12   6   5
# 1789         9   236          9       3  ...   2   8  1183  183   2   6   9
# 1790         0     1          0       0  ...   0   1    19    1   0   0   0
#
#        WB  UN        State
# 0       0   0  Maharashtra
# 1       0   0  Maharashtra
# 2       0   0  Maharashtra
# 3       0   0  Maharashtra
# 4       0   0  Maharashtra
# ...   ...  ..          ...
# 1786  880   0   Lakshdweep
# 1787   13   0   Lakshdweep
# 1788  914   0   Lakshdweep
# 1789  913   0   Lakshdweep
# 1790   15   0   Lakshdweep
#
# [1791 rows x 43 columns]
